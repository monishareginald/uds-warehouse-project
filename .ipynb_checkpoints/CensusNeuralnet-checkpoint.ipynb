# %% [markdown]
# ## Neural Network Model with Top 20 Feature Importances (including census data)

# %%
#import libraries 
import pandas as pd
import geopandas as gpd
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# %%
#read in data
# read in data
parcel_data=pd.read_csv('all_data_joined_2010.csv')
# Out:
# C:\Users\cpugh\AppData\Local\Temp\ipykernel_25220\3879318906.py:3: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   parcel_data=pd.read_csv('all_data_joined_2010.csv')

# %%
# need to set APN to be index so that we can join this back to other information later on
parceldata_10 = parcel_data
parceldata_10.set_index('APN',inplace=True)
parceldata_10.columns
# Out:
# Index(['GEO_ID', 'LAND_VALUE', 'distances', 'building_class', 'year', 'acres',
#        'sqft', 'num_warehouses', 'warehouse_start', 'buit_within_decade',
#        ...
#        'tract_y_y', 'Percent Employee of private company workers',
#        'Percent Self-employed in own incorporated business workers',
#        'Percent Private not-for-profit wage and salary workers',
#        'Percent Local government workers', 'Percent State government workers',
#        'Percent Federal government workers',
#        'Percent Self-employed in own not incorporated business workers',
#        'Percent Unpaid family workers', 'geometry_census'],
#       dtype='object', length=109)

# %%
parceldata_10 = parceldata_10.rename(columns = {'buit_within_decade': 'built_within_decade'})

# %%
# Create a dataset for data as of 2020
parceldata_20=pd.read_csv('data/all_data_joined_2020.csv')

# need to set APN to be index so that we can join this back to other information later on
parceldata_20.set_index('APN',inplace=True)
# Out:
# C:\Users\cpugh\AppData\Local\Temp\ipykernel_25220\2026702094.py:2: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   parceldata_20=pd.read_csv('data/all_data_joined_2020.csv')

# %%
parceldata_20 = parceldata_20.rename(columns = {'buit_within_decade': 'built_within_decade'})

# %% [markdown]
# ## Standardize Data

# %% [markdown]
# Use top 20 feature importances from random forest to run a model with fewer columns that includes census data

# %%
#subset parceldata10 to run model with only top 20 feature importances
parceldata_10 = parceldata_10[['LAND_VALUE', 'ACRES', 'dollars_per_acre', 'distances', 'lon', 'lat',
       'IL_RATIO', 'warehouse_start', 'Industrial', 'Vacant',
       'Percent $10,000-$14,999', 'Percent $100,000 - $124,999',
       'Percent White alone', 'Percent Some other race alone',
       'Percent some_college', 'Percent less_highschool',
       'Percent Renter Occupied', 'Percent No schooling completed',
       'Percent Two or more races:', 'Percent Owner Occupied', 'built_within_decade']]

# %%
#standardize data

cols_to_exclude = ['built_within_decade']

otherCols  = [col for col in parceldata_10.columns if col not in cols_to_exclude]
otherCols
# Out:
# ['LAND_VALUE',
#  'ACRES',
#  'dollars_per_acre',
#  'distances',
#  'lon',
#  'lat',
#  'IL_RATIO',
#  'warehouse_start',
#  'Industrial',
#  'Vacant',
#  'Percent $10,000-$14,999',
#  'Percent $100,000 - $124,999',
#  'Percent White alone',
#  'Percent Some other race alone',
#  'Percent some_college',
#  'Percent less_highschool',
#  'Percent Renter Occupied',
#  'Percent No schooling completed',
#  'Percent Two or more races:',
#  'Percent Owner Occupied']

# %%
parceldata_10[otherCols].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 1367392 entries, 507410018.0 to 320016101.0
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   LAND_VALUE                      1367392 non-null  float64
#  1   ACRES                           1367392 non-null  float64
#  2   dollars_per_acre                1367392 non-null  float64
#  3   distances                       1367392 non-null  float64
#  4   lon                             1367392 non-null  float64
#  5   lat                             1367392 non-null  float64
#  6   IL_RATIO                        1367392 non-null  float64
#  7   warehouse_start                 1367392 non-null  int64
#  8   Industrial                      1367392 non-null  float64
#  9   Vacant                          1367392 non-null  float64
#  10  Percent $10,000-$14,999         1367205 non-null  float64
#  11  Percent $100,000 - $124,999     1367205 non-null  float64
#  12  Percent White alone             1367272 non-null  float64
#  13  Percent Some other race alone   1367272 non-null  float64
#  14  Percent some_college            1367272 non-null  float64
#  15  Percent less_highschool         1367272 non-null  float64
#  16  Percent Renter Occupied         1367205 non-null  float64
#  17  Percent No schooling completed  1367272 non-null  float64
#  18  Percent Two or more races:      1367272 non-null  float64
#  19  Percent Owner Occupied          1367205 non-null  float64
# dtypes: float64(19), int64(1)
# memory usage: 219.1 MB

# %%
#scale "otherCols"
from sklearn import preprocessing
scaler = preprocessing.StandardScaler().fit(parceldata_10[otherCols])

# convert to DataFrame and specify the column names and index
df_scaled = pd.DataFrame(scaler.transform(parceldata_10[otherCols]), 
                         columns=otherCols, index=parceldata_10.index)

# create a DataFrame with these scaled columns joined to the columns that we didn't scale
df_scaled = df_scaled.join(parceldata_10[cols_to_exclude])

df_scaled.head()
# Out:
#              LAND_VALUE     ACRES  dollars_per_acre  distances       lon  \
# APN
# 507410018.0   -0.176363 -0.082295         -0.579267  -0.104698  2.400819
# 507450006.0   -0.176363 -0.084488         -0.579267  -0.135056  2.415295
# 507450007.0   -0.176363 -0.082739         -0.579267  -0.138133  2.416776
# 507450018.0   -0.176363 -0.083791         -0.579267  -0.142373  2.418841
# 507450019.0   -0.176363 -0.082942         -0.579267  -0.145513  2.420366
#
#                   lat  IL_RATIO  warehouse_start  Industrial    Vacant  ...  \
# APN                                                                     ...
# 507410018.0 -0.679082  0.038584        -0.045062   -0.097781 -0.419984  ...
# 507450006.0 -0.678996 -0.084727        -0.045062   -0.097781 -0.419984  ...
# 507450007.0 -0.678989 -0.027228        -0.045062   -0.097781 -0.419984  ...
# 507450018.0 -0.678983 -0.003590        -0.045062   -0.097781 -0.419984  ...
# 507450019.0 -0.678975  0.029702        -0.045062   -0.097781 -0.419984  ...
#
#              Percent $100,000 - $124,999  Percent White alone  \
# APN
# 507410018.0                    -0.238933             1.249344
# 507450006.0                    -0.238933             1.249344
# 507450007.0                    -0.238933             1.249344
# 507450018.0                    -0.238933             1.249344
# 507450019.0                    -0.238933             1.249344
#
#              Percent Some other race alone  Percent some_college  \
# APN
# 507410018.0                       -1.10619             -0.378944
# 507450006.0                       -1.10619             -0.378944
# 507450007.0                       -1.10619             -0.378944
# 507450018.0                       -1.10619             -0.378944
# 507450019.0                       -1.10619             -0.378944
#
#              Percent less_highschool  Percent Renter Occupied  \
# APN
# 507410018.0                -0.900189                 0.470421
# 507450006.0                -0.900189                 0.470421
# 507450007.0                -0.900189                 0.470421
# 507450018.0                -0.900189                 0.470421
# 507450019.0                -0.900189                 0.470421
#
#              Percent No schooling completed  Percent Two or more races:  \
# APN
# 507410018.0                       -0.073745                   -0.510092
# 507450006.0                       -0.073745                   -0.510092
# 507450007.0                       -0.073745                   -0.510092
# 507450018.0                       -0.073745                   -0.510092
# 507450019.0                       -0.073745                   -0.510092
#
#              Percent Owner Occupied  built_within_decade
# APN
# 507410018.0               -0.470421                    0
# 507450006.0               -0.470421                    0
# 507450007.0               -0.470421                    0
# 507450018.0               -0.470421                    0
# 507450019.0               -0.470421                    0
#
# [5 rows x 21 columns]

# %%
# define variables 
cols=df_scaled.columns.to_list()
xvars=[col for col in cols if col not in ('APN', 'built_within_decade')]
yvar = 'built_within_decade'

# create a dataframe with no NaNs
parceldata_10_model = df_scaled[xvars+[yvar]].dropna()

# create train-test split
X_train, X_test, y_train, y_test = train_test_split(
    parceldata_10_model[xvars], parceldata_10_model[yvar], test_size = 0.25, random_state = 1)

# %%
parceldata_10_model[xvars].describe() ##check that it is standardized
# Out:
#          LAND_VALUE         ACRES  dollars_per_acre     distances  \
# count  1.367205e+06  1.367205e+06      1.367205e+06  1.367205e+06
# mean  -1.461734e-04 -9.574456e-05      5.011347e-05 -3.081674e-05
# std    9.967456e-01  9.997190e-01      1.000047e+00  1.000033e+00
# min   -1.763634e-01 -9.605143e-02     -5.792667e-01 -7.538905e-01
# 25%   -1.288767e-01 -9.117835e-02     -4.788364e-01 -5.883514e-01
# 50%   -7.700293e-02 -8.997856e-02     -2.079384e-01 -3.774103e-01
# 75%   -7.789000e-03 -8.177318e-02      1.332609e-01  4.902608e-02
# max    3.711867e+02  1.021523e+02      2.534643e+02  5.197013e+00
#
#                 lon           lat      IL_RATIO  warehouse_start  \
# count  1.367205e+06  1.367205e+06  1.367205e+06     1.367205e+06
# mean   8.345338e-05 -1.316080e-04  2.138676e-06    -1.402152e-04
# std    1.000019e+00  9.999651e-01  1.000049e+00     9.984465e-01
# min   -1.805485e+00 -2.060570e+00 -2.485697e-01    -4.506218e-02
# 25%   -6.916307e-01 -6.565307e-01 -1.471523e-01    -4.506218e-02
# 50%   -1.108524e-01 -6.932656e-02 -2.363347e-02    -4.506218e-02
# 75%    4.342576e-01  3.973493e-01  8.734066e-02    -4.506218e-02
# max    2.893679e+00  3.571829e+00  7.737446e+02     2.219156e+01
#
#          Industrial        Vacant  Percent $10,000-$14,999  \
# count  1.367205e+06  1.367205e+06             1.367205e+06
# mean  -6.214289e-05 -1.016438e-05            -7.623443e-16
# std    9.996856e-01  9.999904e-01             1.000000e+00
# min   -9.778105e-02 -4.199843e-01            -1.254650e+00
# 25%   -9.778105e-02 -4.199843e-01            -8.034848e-01
# 50%   -9.778105e-02 -4.199843e-01            -2.104723e-01
# 75%   -9.778105e-02 -4.199843e-01             4.489739e-01
# max    1.022693e+01  2.381042e+00             6.981076e+00
#
#        Percent $100,000 - $124,999  Percent White alone  \
# count                 1.367205e+06         1.367205e+06
# mean                  1.315144e-15         1.404527e-05
# std                   1.000000e+00         1.000020e+00
# min                  -1.913739e+00        -3.316816e+00
# 25%                  -8.116781e-01        -7.060717e-01
# 50%                  -1.506845e-01         3.707831e-02
# 75%                   7.796808e-01         7.573993e-01
# max                   6.351805e+00         1.986975e+00
#
#        Percent Some other race alone  Percent some_college  \
# count                   1.367205e+06          1.367205e+06
# mean                    4.016296e-05          1.112929e-05
# std                     1.000008e+00          1.000021e+00
# min                    -1.496375e+00         -4.154418e+00
# 25%                    -7.773256e-01         -5.366506e-01
# 50%                    -2.167584e-01          8.067208e-02
# 75%                     5.306438e-01          7.217202e-01
# max                     5.124265e+00          2.870220e+00
#
#        Percent less_highschool  Percent Renter Occupied  \
# count             1.367205e+06             1.367205e+06
# mean             -1.136022e-04            -3.096608e-16
# std               9.998932e-01             1.000000e+00
# min              -1.660504e+00            -1.723261e+00
# 25%              -7.567766e-01            -7.142406e-01
# 50%              -2.306041e-01            -2.559880e-01
# 75%               5.296047e-01             4.755092e-01
# max               3.551876e+00             4.503702e+00
#
#        Percent No schooling completed  Percent Two or more races:  \
# count                    1.367205e+06                1.367205e+06
# mean                     5.119446e-06                1.553983e-05
# std                      1.000020e+00                1.000011e+00
# min                     -1.041376e+00               -1.792117e+00
# 25%                     -7.265629e-01               -7.230009e-01
# 50%                     -2.669924e-01               -4.882759e-02
# 75%                      3.971191e-01                6.451575e-01
# max                      9.391960e+00                4.604831e+00
#
#        Percent Owner Occupied
# count            1.367205e+06
# mean             1.199561e-15
# std              1.000000e+00
# min             -4.503702e+00
# 25%             -4.755092e-01
# 50%              2.559880e-01
# 75%              7.142406e-01
# max              1.723261e+00

# %%
#predict
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier(hidden_layer_sizes=(10, 10, 10), max_iter=1000, random_state = 1) ##add random state here or next line & check that it is using the standardized data
mlp.fit(X_train, y_train)
y_pred = mlp.predict(X_test)

# %%
# stop if the length of the predictions doesn't match the training dataset
assert len(X_test)==len(y_pred)

# %%
#check how it did
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    341688
#            1       0.60      0.37      0.46       114
#
#     accuracy                           1.00    341802
#    macro avg       0.80      0.68      0.73    341802
# weighted avg       1.00      1.00      1.00    341802

# %%
print('Predicted fraction True: {:.4f}. Actual fraction True: {:.4f}'.format(
    y_pred.mean(), y_test.mean()))
# Out:
# Predicted fraction True: 0.0002. Actual fraction True: 0.0003

# %%
#confusion matrix
ConfusionMatrixDisplay.from_predictions(y_test, y_pred)
plt.savefig('confusion_matrix_Neuralnet.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ### Apply Model to 2020 Dataset

# %% [markdown]
# ### Standardize New Dataframe

# %%
#subset parceldata20 to run model with only top 20 feature importances
parceldata_20 = parceldata_20[['LAND_VALUE', 'ACRES', 'dollars_per_acre', 'distances', 'lon', 'lat',
       'IL_RATIO', 'warehouse_start', 'Industrial', 'Vacant',
       'Percent $10,000-$14,999', 'Percent $100,000 - $124,999',
       'Percent White alone', 'Percent Some other race alone',
       'Percent some_college', 'Percent less_highschool',
       'Percent Renter Occupied', 'Percent No schooling completed',
       'Percent Two or more races:', 'Percent Owner Occupied', 'built_within_decade']]

# %%
#select columns to standardize

cols_to_exclude = ['built_within_decade']

otherCols  = [col for col in parceldata_20.columns if col not in cols_to_exclude]
otherCols
# Out:
# ['LAND_VALUE',
#  'ACRES',
#  'dollars_per_acre',
#  'distances',
#  'lon',
#  'lat',
#  'IL_RATIO',
#  'warehouse_start',
#  'Industrial',
#  'Vacant',
#  'Percent $10,000-$14,999',
#  'Percent $100,000 - $124,999',
#  'Percent White alone',
#  'Percent Some other race alone',
#  'Percent some_college',
#  'Percent less_highschool',
#  'Percent Renter Occupied',
#  'Percent No schooling completed',
#  'Percent Two or more races:',
#  'Percent Owner Occupied']

# %%
#scale "otherCols"
from sklearn import preprocessing
scaler = preprocessing.StandardScaler().fit(parceldata_20[otherCols])

# convert to DataFrame and specify the column names and index
df_scaled2 = pd.DataFrame(scaler.transform(parceldata_20[otherCols]), 
                         columns=otherCols, index=parceldata_20.index)

# create a DataFrame with these scaled columns joined to the columns that we didn't scale
df_scaled2 = df_scaled2.join(parceldata_20[cols_to_exclude])

df_scaled2.head()
# Out:
#              LAND_VALUE     ACRES  dollars_per_acre  distances       lon  \
# APN
# 210080008.0    0.464934 -0.063727         -0.061345  -0.707050 -0.329750
# 210060035.0   -0.176363 -0.087830         -0.579267  -0.700741 -0.326391
# 210210051.0    0.062076 -0.094288          2.949973  -0.718649 -0.339521
# 210210076.0   -0.176363 -0.080788         -0.579267  -0.721402 -0.338584
# 210210046.0   -0.062818 -0.094354          1.167120  -0.722629 -0.340775
#
#                   lat  IL_RATIO  warehouse_start  Industrial    Vacant  ...  \
# APN                                                                     ...
# 210080008.0 -0.109340 -0.174931        -0.048735   -0.097781 -0.419984  ...
# 210060035.0 -0.106611 -0.248570        -0.048735   -0.097781 -0.419984  ...
# 210210051.0 -0.117267 -0.044804        -0.048735   -0.097781 -0.419984  ...
# 210210076.0 -0.117239 -0.248570        -0.048735   -0.097781 -0.419984  ...
# 210210046.0 -0.117138  0.099240        -0.048735   -0.097781 -0.419984  ...
#
#              Percent $100,000 - $124,999  Percent White alone  \
# APN
# 210080008.0                    -0.919021            -2.178635
# 210060035.0                    -0.919021            -2.178635
# 210210051.0                    -0.919021            -2.178635
# 210210076.0                    -0.919021            -2.178635
# 210210046.0                    -0.919021            -2.178635
#
#              Percent Some other race alone  Percent some_college  \
# APN
# 210080008.0                       1.955923              1.311518
# 210060035.0                       1.955923              1.311518
# 210210051.0                       1.955923              1.311518
# 210210076.0                       1.955923              1.311518
# 210210046.0                       1.955923              1.311518
#
#              Percent less_highschool  Percent Renter Occupied  \
# APN
# 210080008.0                 0.736955                 0.852966
# 210060035.0                 0.736955                 0.852966
# 210210051.0                 0.736955                 0.852966
# 210210076.0                 0.736955                 0.852966
# 210210046.0                 0.736955                 0.852966
#
#              Percent No schooling completed  Percent Two or more races:  \
# APN
# 210080008.0                         2.38736                   -1.649193
# 210060035.0                         2.38736                   -1.649193
# 210210051.0                         2.38736                   -1.649193
# 210210076.0                         2.38736                   -1.649193
# 210210046.0                         2.38736                   -1.649193
#
#              Percent Owner Occupied  built_within_decade
# APN
# 210080008.0               -0.852966                    0
# 210060035.0               -0.852966                    0
# 210210051.0               -0.852966                    0
# 210210076.0               -0.852966                    0
# 210210046.0               -0.852966                    0
#
# [5 rows x 21 columns]

# %%
# define variables 
cols=df_scaled2.columns.to_list()
xvars=[col for col in cols if col not in ('APN', 'built_within_decade')]
yvar = 'built_within_decade'

# create a dataframe with no NaNs
parceldata_20_model = df_scaled2[xvars+[yvar]].dropna()

# %%
# apply predictions from previous model to test dataset
X_test=parceldata_20_model[xvars]
y_pred = mlp.predict(X_test)

# %%
# stop if lengths don't match
assert len(X_test)==len(y_pred)
# how many does it predict?
print('Predicted fraction True: {:.4f}'.format(y_pred.mean()))
print('Predicted number True: {:.0f}'.format(y_pred.sum()))
# Out:
# Predicted fraction True: 0.0001
# Predicted number True: 91

# %%
# create a dataframe of predictions about whether or not a parcel will have a warehouse built on it within 10 years & join this to the full df
predictions = pd.DataFrame(mlp.predict_proba(X_test),columns = ['pred_noWH', 'pred_WH'])
predictions= predictions.join((X_test).reset_index())
predictions.set_index('APN',inplace=True)
predictions.head()
# Out:
#              pred_noWH       pred_WH  LAND_VALUE     ACRES  dollars_per_acre  \
# APN
# 210080008.0    0.99999  9.676933e-06    0.464934 -0.063727         -0.061345
# 210060035.0    1.00000  4.026143e-07   -0.176363 -0.087830         -0.579267
# 210210051.0    1.00000  8.415509e-13    0.062076 -0.094288          2.949973
# 210210076.0    1.00000  4.148455e-07   -0.176363 -0.080788         -0.579267
# 210210046.0    1.00000  2.817045e-09   -0.062818 -0.094354          1.167120
#
#              distances       lon       lat  IL_RATIO  warehouse_start  ...  \
# APN                                                                    ...
# 210080008.0  -0.707050 -0.329750 -0.109340 -0.174931        -0.048735  ...
# 210060035.0  -0.700741 -0.326391 -0.106611 -0.248570        -0.048735  ...
# 210210051.0  -0.718649 -0.339521 -0.117267 -0.044804        -0.048735  ...
# 210210076.0  -0.721402 -0.338584 -0.117239 -0.248570        -0.048735  ...
# 210210046.0  -0.722629 -0.340775 -0.117138  0.099240        -0.048735  ...
#
#              Percent $10,000-$14,999  Percent $100,000 - $124,999  \
# APN
# 210080008.0                -1.082431                    -0.919021
# 210060035.0                -1.082431                    -0.919021
# 210210051.0                -1.082431                    -0.919021
# 210210076.0                -1.082431                    -0.919021
# 210210046.0                -1.082431                    -0.919021
#
#              Percent White alone  Percent Some other race alone  \
# APN
# 210080008.0            -2.178635                       1.955923
# 210060035.0            -2.178635                       1.955923
# 210210051.0            -2.178635                       1.955923
# 210210076.0            -2.178635                       1.955923
# 210210046.0            -2.178635                       1.955923
#
#              Percent some_college  Percent less_highschool  \
# APN
# 210080008.0              1.311518                 0.736955
# 210060035.0              1.311518                 0.736955
# 210210051.0              1.311518                 0.736955
# 210210076.0              1.311518                 0.736955
# 210210046.0              1.311518                 0.736955
#
#              Percent Renter Occupied  Percent No schooling completed  \
# APN
# 210080008.0                 0.852966                         2.38736
# 210060035.0                 0.852966                         2.38736
# 210210051.0                 0.852966                         2.38736
# 210210076.0                 0.852966                         2.38736
# 210210046.0                 0.852966                         2.38736
#
#              Percent Two or more races:  Percent Owner Occupied
# APN
# 210080008.0                   -1.649193               -0.852966
# 210060035.0                   -1.649193               -0.852966
# 210210051.0                   -1.649193               -0.852966
# 210210076.0                   -1.649193               -0.852966
# 210210046.0                   -1.649193               -0.852966
#
# [5 rows x 22 columns]

# %%
#predictions.to_csv('predictions_neuralnet1.csv')
