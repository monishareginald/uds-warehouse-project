# %% [markdown]
# # Exploring and Preparing Land Prices Data by Census Tract
#
# [Data Source](https://www.fhfa.gov/PolicyProgramsResearch/Research/Pages/wp1901.aspx)
#
#
# [FAQs](https://www.fhfa.gov/PolicyProgramsResearch/Research/PaperDocuments/FAQs-Land-10-28-20.pdf)
#
# In this notebook, I will prepare our land values data for use in our decision tree for our random forest evaluation. I will filter down to the census tracts within the areas we are interested in, I will clean the data and look for NAs and duplicates, I will join the data to census tract boundaries, and I will prepare the data to be spatially joined to the parcel level SCAG data.

# %% [markdown]
# First: Look at Census Tract level land values data, this dataset has residential data only.

# %%
import pandas as pd

alldf = pd.read_csv('land_vals.csv', encoding_errors = 'ignore')

# %%
#filter down to counties of interest
socal = alldf[(alldf.County == 'Riverside County')|(alldf.County == 'San Bernardino County')]
# Out:
#            State              County  Census Tract  \
# 3248  California  Los Angeles County    6037501900
# 2500  California  Los Angeles County    6037101300
# 3240  California  Los Angeles County    6037500600
# 2862  California  Los Angeles County    6037262400
# 4457  California    Riverside County    6065041702
# 3612  California  Los Angeles County    6037910603
# 3058  California  Los Angeles County    6037403402
# 2872  California  Los Angeles County    6037265201
# 3456  California  Los Angeles County    6037620522
# 3587  California  Los Angeles County    6037901011
#
#       Land Value\n(1/4 Acre Lot, Standardized)  Land Value\n(Per Acre, As-Is)  \
# 3248                                    318700                        1832100
# 2500                                    406500                        1826100
# 3240                                    287400                        1777100
# 2862                                   2146700                        5212500
# 4457                                    192400                         887700
# 3612                                     55300                         294900
# 3058                                    480800                        2291800
# 2872                                   2231000                        9977600
# 3456                                    951600                        5036700
# 3587                                     61200                         285400
#
#      Land Share of Property Value  Lot Size  Interior Square Feet  \
# 3248                        0.627      6460                  1290
# 2500                        0.621      8890                  1580
# 3240                        0.612      5740                  1260
# 2862                        0.747     21460                  3610
# 4457                        0.539      8800                  1290
# 3612                        0.218      7120                  1600
# 3058                        0.671      8400                  1870
# 2872                        0.754      9170                  3350
# 3456                        0.747      7210                  2260
# 3587                        0.212      8410                  1960
#
#       Property Value (Standardized)  Property Value (As-is)
# 3248                         621000                  433300
# 2500                         733100                  599700
# 3240                         572400                  383100
# 2862                        2261300                 3439000
# 4457                         450500                  332600
# 3612                         270800                  221500
# 3058                         731100                  658500
# 2872                        2221800                 2784400
# 3456                        1150100                 1116100
# 3587                         278800                  260000

# %%
import geopandas as gpd

tracts = gpd.read_file('data/tl_2019_06_tract/tl_2019_06_tract.shp')
tracts.dtypes
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File fiona\ogrext.pyx:136, in fiona.ogrext.gdal_open_vector()
#
# File fiona\_err.pyx:291, in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: tl_2019_06_tract/tl_2019_06_tract.shp: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# Cell In[2], line 3
#       1 import geopandas as gpd
# ----> 3 tracts = gpd.read_file('tl_2019_06_tract/tl_2019_06_tract.shp')
#       4 tracts.dtypes
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\geopandas\io\file.py:248, in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     245     else:
#     246         path_or_bytes = filename
# --> 248     return _read_file_fiona(
#     249         path_or_bytes, from_bytes, bbox=bbox, mask=mask, rows=rows, **kwargs
#     250     )
#     252 else:
#     253     raise ValueError(f"unknown engine '{engine}'")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\geopandas\io\file.py:289, in _read_file_fiona(path_or_bytes, from_bytes, bbox, mask, rows, where, **kwargs)
#     286     reader = fiona.open
#     288 with fiona_env():
# --> 289     with reader(path_or_bytes, **kwargs) as features:
#     290         crs = features.crs_wkt
#     291         # attempt to get EPSG code
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\fiona\env.py:457, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwds)
#     454     session = DummySession()
#     456 with env_ctor(session=session):
# --> 457     return f(*args, **kwds)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\fiona\__init__.py:308, in open(fp, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt, allow_unsupported_drivers, **kwargs)
#     305     path = parse_path(fp)
#     307 if mode in ("a", "r"):
# --> 308     colxn = Collection(
#     309         path,
#     310         mode,
#     311         driver=driver,
#     312         encoding=encoding,
#     313         layer=layer,
#     314         enabled_drivers=enabled_drivers,
#     315         allow_unsupported_drivers=allow_unsupported_drivers,
#     316         **kwargs
#     317     )
#     318 elif mode == "w":
#     319     colxn = Collection(
#     320         path,
#     321         mode,
#    (...)
#     330         **kwargs
#     331     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\fiona\collection.py:243, in Collection.__init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, ignore_fields, ignore_geometry, include_fields, wkt_version, allow_unsupported_drivers, **kwargs)
#     241 if self.mode == "r":
#     242     self.session = Session()
# --> 243     self.session.start(self, **kwargs)
#     244 elif self.mode in ("a", "w"):
#     245     self.session = WritingSession()
#
# File fiona\ogrext.pyx:588, in fiona.ogrext.Session.start()
#
# File fiona\ogrext.pyx:143, in fiona.ogrext.gdal_open_vector()
#
# DriverError: tl_2019_06_tract/tl_2019_06_tract.shp: No such file or directory

# %%
tracts['GEOID'] = tracts['GEOID'].astype('float')
# Out:
#   STATEFP COUNTYFP TRACTCE         GEOID     NAME              NAMELSAD  \
# 0      06      037  139301  6.037139e+09  1393.01  Census Tract 1393.01
# 1      06      037  139302  6.037139e+09  1393.02  Census Tract 1393.02
# 2      06      037  139502  6.037140e+09  1395.02  Census Tract 1395.02
# 3      06      037  139600  6.037140e+09     1396     Census Tract 1396
# 4      06      037  139701  6.037140e+09  1397.01  Census Tract 1397.01
#
#    MTFCC FUNCSTAT    ALAND  AWATER     INTPTLAT      INTPTLON  \
# 0  G5020        S  2865657       0  +34.1781538  -118.5581265
# 1  G5020        S   338289       0  +34.1767230  -118.5383655
# 2  G5020        S  1047548       0  +34.1628402  -118.5263110
# 3  G5020        S  2477482       0  +34.1640599  -118.5101001
# 4  G5020        S  3396396    2411  +34.1574290  -118.4954117
#
#                                             geometry
# 0  POLYGON ((-118.57150 34.17758, -118.57148 34.1...
# 1  POLYGON ((-118.54073 34.18019, -118.54070 34.1...
# 2  POLYGON ((-118.53225 34.16201, -118.53177 34.1...
# 3  POLYGON ((-118.51858 34.15858, -118.51858 34.1...
# 4  POLYGON ((-118.50980 34.15691, -118.50848 34.1...

# %%
socal = socal.rename(columns = {'Census Tract':'GEOID'})
socal['GEOID'] = socal['GEOID'].astype('float')
socal = socal.set_index('GEOID')

# %%
tracts = tracts.set_index('GEOID')

# %%
socal.shape
# Out:
# (1889, 9)

# %%
socalGdf = socal.join(tracts[['geometry']], on= 'GEOID')
socalGdf.sample(3)
socalGdf.head()
# Out:
#                    State              County  \
# GEOID
# 6.037101e+09  California  Los Angeles County
# 6.037101e+09  California  Los Angeles County
# 6.037101e+09  California  Los Angeles County
# 6.037101e+09  California  Los Angeles County
# 6.037101e+09  California  Los Angeles County
#
#               Land Value\n(1/4 Acre Lot, Standardized)  \
# GEOID
# 6.037101e+09                                    325200
# 6.037101e+09                                    327100
# 6.037101e+09                                    302800
# 6.037101e+09                                    325600
# 6.037101e+09                                    406500
#
#               Land Value\n(Per Acre, As-Is) Land Share of Property Value  \
# GEOID
# 6.037101e+09                        1722700                        0.568
# 6.037101e+09                        1233000                        0.538
# 6.037101e+09                        1467400                        0.503
# 6.037101e+09                        1684900                        0.554
# 6.037101e+09                        1826100                        0.621
#
#               Lot Size  Interior Square Feet  Property Value (Standardized)  \
# GEOID
# 6.037101e+09      7100                  1400                         668000
# 6.037101e+09     11340                  1850                         652600
# 6.037101e+09      7840                  1600                         660200
# 6.037101e+09      7170                  1400                         683800
# 6.037101e+09      8890                  1580                         733100
#
#               Property Value (As-is)  \
# GEOID
# 6.037101e+09                  494500
# 6.037101e+09                  596600
# 6.037101e+09                  525100
# 6.037101e+09                  500800
# 6.037101e+09                  599700
#
#                                                        geometry
# GEOID
# 6.037101e+09  POLYGON ((-118.30229 34.25870, -118.30091 34.2...
# 6.037101e+09  POLYGON ((-118.30334 34.27371, -118.30330 34.2...
# 6.037101e+09  POLYGON ((-118.29945 34.25598, -118.29792 34.2...
# 6.037101e+09  POLYGON ((-118.28592 34.25227, -118.28592 34.2...
# 6.037101e+09  POLYGON ((-118.27822 34.25068, -118.27822 34.2...

# %% [markdown]
# # Parcel Level Data
#
# Now, instead try the parcel level. Data source: https://gis.rivco.org/pages/data-distribution (Parcels Attributed) 2021

# %%
import pandas as pd

riverside = pd.read_csv('riv_parcels_values.csv')
# Out:
# C:\Users\LucyBriggs\AppData\Local\Temp\ipykernel_11788\449641197.py:3: DtypeWarning: Columns (5,6,8,9,10,11,12,13,14,23,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   riverside = pd.read_csv('riv_parcels_values.csv')

# %%
riverside.shape
# Out:
# (827053, 35)

# %%
riverside.columns
# Out:
# Index(['OID_', 'APN', 'FLAG', 'MAIL_STREET', 'MAIL_CITY', 'SITUS_STREET',
#        'SITUS_CITY', 'STREET_NUMBER', 'STREET_PREDIRECTION', 'STREET_NAME',
#        'STREET_TYPE', 'STREET_SUFFIX', 'UNIT_NUMBER', 'CITY', 'ZIP_CODE',
#        'CLASS_CODE', 'MULTIPLE', 'SUBDIVISION_NAME', 'ACREAGE',
#        'RECORDER_MAP_TYPE', 'BOOK', 'PAGE', 'MAP_BOOK_PAGE', 'COUNTY_CODE',
#        'LOT_TYPE', 'LOT', 'BLOCK', 'CAME_FROM', 'TAX_RATE_AREA', 'LAND',
#        'STRUCTURES', 'PRIMARY_OWNER', 'ALL_OWNER_LIST', 'SHAPE_Length',
#        'SHAPE_Area'],
#       dtype='object')

# %%
desired_cols = ['APN', 'ACREAGE', 'LOT_TYPE', 'CLASS_CODE','LAND','SHAPE_Length', 'SHAPE_Area']
riverside = riverside[desired_cols]
riverside = riverside.dropna()
riverside.head()
# Out:
#            APN  ACREAGE LOT_TYPE                                  CLASS_CODE
# 349  101160001     1.37      Lot  Vacant Land - Predominate Agricultural Use  \
# 356  101200001     0.26      Lot                           HOMESITE/< 1 ACRE
# 357  101200010     0.21      Lot  Vacant Land - Predominate Agricultural Use
# 358  101200011     0.21      Lot                           HOMESITE/< 1 ACRE
# 379  101160002     0.87      Lot  Vacant Land - Predominate Agricultural Use
#
#         LAND  SHAPE_Length    SHAPE_Area
# 349   1612.0   1034.716993  63941.295998
# 356  33813.0    482.028560  11167.476229
# 357   4751.0    429.474623   9283.691471
# 358   7803.0    429.620279   9288.048070
# 379   1048.0    796.745006  39647.856447

# %%
riverside['APN'].is_unique
# Out:
# True

# %%
riverside = riverside[riverside.LAND!=0]
riverside.shape
# Out:
# (732615, 7)

# %%
riverside['LAND'].describe()
# Out:
# count    7.326150e+05
# mean     1.238838e+05
# std      4.486991e+05
# min      1.000000e+00
# 25%      4.707800e+04
# 50%      7.649800e+04
# 75%      1.158850e+05
# max      7.907040e+07
# Name: LAND, dtype: float64

# %%
colsriv = ['APN', 'LAND']
riverside = riverside[colsriv]
riverside.rename(columns = {'LAND':'landval'}, inplace = True)

# %%
rivgeom = gpd.read_file('data/riversideparcelgeom.zip')
rivgeom.head()
# Out:
#          APN FLAG MAIL_STREE MAIL_CITY SITUS_STRE SITUS_CITY  STREET_NUM
# 0  727271026  NaN        NaN       NaN        NaN        NaN           0  \
# 1  779201018  NaN        NaN       NaN        NaN        NaN           0
# 2  182084014  NaN        NaN       NaN        NaN        NaN           0
# 3  290080018  NaN        NaN       NaN        NaN        NaN           0
# 4  300090005  NaN        NaN       NaN        NaN        NaN           0
#
#   STREET_PRE STREET_NAM STREET_TYP  ... BLOCK CAME_FROM TAX_RATE_A LAND
# 0        NaN        NaN        NaN  ...   NaN       NaN        NaN  0.0  \
# 1        NaN        NaN        NaN  ...   NaN       NaN        NaN  0.0
# 2        NaN        NaN        NaN  ...   NaN       NaN        NaN  0.0
# 3        NaN        NaN        NaN  ...   NaN       NaN        NaN  0.0
# 4        NaN        NaN        NaN  ...   NaN       NaN        NaN  0.0
#
#   STRUCTURES PRIMARY_OW ALL_OWNER_   Shape_Leng     Shape_Area
# 0        0.0        NaN        NaN   750.928966   20576.810542  \
# 1        0.0        NaN        NaN   269.157285    3783.144844
# 2        0.0        NaN        NaN  1118.738635    8969.624746
# 3        0.0        NaN        NaN  1294.601223   97648.076503
# 4        0.0        NaN        NaN  3208.975260  559323.813624
#
#                                             geometry
# 0  POLYGON ((6614112.612 2150594.430, 6614159.734...
# 1  POLYGON ((6570999.526 2188909.899, 6570971.279...
# 2  POLYGON ((6204064.073 2310041.573, 6204067.037...
# 3  POLYGON ((6196599.470 2223714.710, 6196589.146...
# 4  POLYGON ((6272976.191 2246330.019, 6272976.353...
#
# [5 rows x 35 columns]

# %%
cols = ['APN', 'geometry']
rivgeom2 = rivgeom[cols]
rivgeom2['APN'] = rivgeom2['APN'].astype('int64')
# Out:
# C:\Users\LucyBriggs\AppData\Local\Programs\Python\Python311\Lib\site-packages\geopandas\geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
rivfinal = riverside.join(rivgeom2.set_index('APN'), on = 'APN', how = 'left').reset_index()

# %%
rivfinal.head()
# Out:
#    index        APN  landval
# 0    349  101160001   1612.0  \
# 1    356  101200001  33813.0
# 2    357  101200010   4751.0
# 3    358  101200011   7803.0
# 4    379  101160002   1048.0
#
#                                             geometry
# 0  POLYGON ((6143486.288 2271147.710, 6143442.181...
# 1  POLYGON ((6131609.852 2261798.072, 6131596.895...
# 2  POLYGON ((6131189.648 2261139.189, 6131129.648...
# 3  POLYGON ((6131249.649 2261140.232, 6131199.588...
# 4  POLYGON ((6144040.701 2271098.313, 6143847.698...

# %%
rivGdf = gpd.GeoDataFrame(rivfinal, geometry='geometry')

# %%
rivGdf.to_file("riversideparcels/riversideparcels.shp", driver = 'ESRI Shapefile')
