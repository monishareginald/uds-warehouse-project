# %% [markdown]
# ## Demographic Data In San Bernardino + Riverside

# %% [markdown]
# ### Race & Housing (Rent/Own)

# %%
import requests

# %%
import geopandas as gpd
import pandas as pd

# %% [markdown]
# ### Get 2009 Data on Race from Table B02001

# %%
#for SB County
r = requests.get('https://api.census.gov/data/2009/acs/acs5?get=group(B02001),geometry,&for=tract:*&in=state:06&in=county:071')
censusdata = r.json()
#specify column names
column_names = censusdata[0]
data_rows = censusdata[1:]
df_SB_race = pd.DataFrame(data_rows, columns=column_names)


#get it for Riverside
r = requests.get('https://api.census.gov/data/2009/acs/acs5?get=group(B02001),geometry,&for=tract:*&in=state:06&in=county:065')
censusdata = r.json()
#specify column names
column_names = censusdata[0]
data_rows = censusdata[1:]
#create dataframe
df_R_race =  pd.DataFrame(data_rows, columns=column_names)
df_R_race.head(2)
# Out:
#   B02001_001E B02001_001EA B02001_001M B02001_001MA B02001_002E B02001_002EA  \
# 0        9277         None         707         None        6729         None
# 1       12791         None         674         None       11321         None
#
#   B02001_002M B02001_002MA B02001_003E B02001_003EA  ... B02001_009MA  \
# 0         754         None         274         None  ...         None
# 1         680         None         237         None  ...         None
#
#   B02001_010E B02001_010EA B02001_010M B02001_010MA                GEO_ID  \
# 0         619         None         274         None  1400000US06065043223
# 1         204         None         139         None  1400000US06065043224
#
#                                                 NAME state county   tract
# 0  Census Tract 432.23, Riverside County, California    06    065  043223
# 1  Census Tract 432.24, Riverside County, California    06    065  043224
#
# [2 rows x 45 columns]

# %% [markdown]
# ### Use API to get the 2009 Housing Data (variables 'B19013_001E':'Median HH Income','B25003_001E':'Total Occupied','B25003_002E':'Owner Occupied','B25003_003E':'Renter Occupied')

# %%
#get 2009 housing columns
#SB
r = requests.get('https://api.census.gov/data/2009/acs/acs5?get=B19013_001E,B25003_001E,B25003_002E,B25003_003E&for=tract:*&in=state:06&in=county:071')
censusdata = r.json()
#df_SB_house = pd.DataFrame(censusdata)
#specify column names
column_names = censusdata[0]
data_rows = censusdata[1:]
#create dataframe
df_SB_house = pd.DataFrame(data_rows, columns=column_names)
df_SB_house.info
# Out:
# <bound method DataFrame.info of     B19013_001E B25003_001E B25003_002E B25003_003E state county   tract
# 0         77134        1563        1135         428    06    071  000103
# 1         99359        1808        1476         332    06    071  000104
# 2        109018        1782        1449         333    06    071  000105
# 3        118598        3323        3035         288    06    071  000106
# 4         93355         893         747         146    06    071  000107
# ..          ...         ...         ...         ...   ...    ...     ...
# 239       52159        1282         849         433    06    071  011900
# 240       53201        3951        2242        1709    06    071  012000
# 241       47091        4920        3703        1217    06    071  012100
# 242       30000         710         570         140    06    071  940100
# 243      126250           4           2           2    06    071  940500
#
# [244 rows x 7 columns]>

# %%
#Riverside
r = requests.get('https://api.census.gov/data/2009/acs/acs5?get=B19013_001E,B25003_001E,B25003_002E,B25003_003E&for=tract:*&in=state:06&in=county:065')
censusdata = r.json()
#df_R_house = pd.DataFrame(censusdata)
#specify column names
column_names = censusdata[0]
data_rows = censusdata[1:]
#create dataframe
df_R_house = pd.DataFrame(data_rows, columns=column_names)
df_R_house.info
# Out:
# <bound method DataFrame.info of     B19013_001E B25003_001E B25003_002E B25003_003E state county   tract
# 0         71775        2809        2174         635    06    065  043223
# 1        108708        3853        3602         251    06    065  043224
# 2         69173        2675        2145         530    06    065  043225
# 3         67813        2182        1986         196    06    065  043304
# 4         53998        3089        2584         505    06    065  043305
# ..          ...         ...         ...         ...   ...    ...     ...
# 338       95990        1621        1381         240    06    065  043218
# 339       74347        3569        2695         874    06    065  043219
# 340       50665        1561         526        1035    06    065  043220
# 341       90652        5712        4635        1077    06    065  043221
# 342      106098        1234        1169          65    06    065  043222
#
# [343 rows x 7 columns]>

# %%
#Join the riverside race and housing data
riverside = pd.merge(df_R_house, df_R_race, on='tract')

# %%
#Join the SB race and housing data
SB = pd.merge(df_SB_house, df_SB_race, on='tract')

# %%
SB.info
# Out:
# <bound method DataFrame.info of     B19013_001E B25003_001E B25003_002E B25003_003E state_x county_x   tract  \
# 0         77134        1563        1135         428      06      071  000103
# 1         99359        1808        1476         332      06      071  000104
# 2        109018        1782        1449         333      06      071  000105
# 3        118598        3323        3035         288      06      071  000106
# 4         93355         893         747         146      06      071  000107
# ..          ...         ...         ...         ...     ...      ...     ...
# 239       52159        1282         849         433      06      071  011900
# 240       53201        3951        2242        1709      06      071  012000
# 241       47091        4920        3703        1217      06      071  012100
# 242       30000         710         570         140      06      071  940100
# 243      126250           4           2           2      06      071  940500
#
#     B02001_001E B02001_001EA B02001_001M  ... B02001_009M B02001_009MA  \
# 0          4531         None         370  ...         210         None
# 1          6593         None         413  ...          34         None
# 2          6368         None         463  ...          98         None
# 3         11671         None         603  ...         105         None
# 4          3023         None         232  ...          63         None
# ..          ...          ...         ...  ...         ...          ...
# 239        4032         None         473  ...         129         None
# 240       12026         None         701  ...          50         None
# 241       14280         None         999  ...         182         None
# 242        1330         None         237  ...         132         None
# 243          19         None          15  ...           3         None
#
#     B02001_010E B02001_010EA B02001_010M B02001_010MA                GEO_ID  \
# 0           111         None          66         None  1400000US06071000103
# 1            86         None          71         None  1400000US06071000104
# 2           277         None         218         None  1400000US06071000105
# 3           401         None         239         None  1400000US06071000106
# 4            48         None          48         None  1400000US06071000107
# ..          ...          ...         ...          ...                   ...
# 239         169         None         140         None  1400000US06071011900
# 240         672         None         352         None  1400000US06071012000
# 241         486         None         243         None  1400000US06071012100
# 242          68         None          69         None  1400000US06071940100
# 243           0         None         132         None  1400000US06071940500
#
#                                                   NAME state_y county_y
# 0    Census Tract 1.03, San Bernardino County, Cali...      06      071
# 1    Census Tract 1.04, San Bernardino County, Cali...      06      071
# 2    Census Tract 1.05, San Bernardino County, Cali...      06      071
# 3    Census Tract 1.06, San Bernardino County, Cali...      06      071
# 4    Census Tract 1.07, San Bernardino County, Cali...      06      071
# ..                                                 ...     ...      ...
# 239  Census Tract 119, San Bernardino County, Calif...      06      071
# 240  Census Tract 120, San Bernardino County, Calif...      06      071
# 241  Census Tract 121, San Bernardino County, Calif...      06      071
# 242  Census Tract 9401, San Bernardino County, Cali...      06      071
# 243  Census Tract 9405, San Bernardino County, Cali...      06      071
#
# [244 rows x 51 columns]>

# %%
#create a single df for SB & Riverside --> calling it GDF to avoid having to change all the code below, but need to add in geometry column 
gdf = pd.concat([riverside,SB], ignore_index=True)

# %%
gdf.sample(1)
# Out:
#    B19013_001E B25003_001E B25003_002E B25003_003E state_x county_x   tract  \
# 83       45839        3053        1618        1435      06      065  045106
#
#    B02001_001E B02001_001EA B02001_001M  ... B02001_009M B02001_009MA  \
# 83        5530         None         596  ...          77         None
#
#    B02001_010E B02001_010EA B02001_010M B02001_010MA                GEO_ID  \
# 83         103         None          60         None  1400000US06065045106
#
#                                                  NAME state_y county_y
# 83  Census Tract 451.06, Riverside County, California      06      065
#
# [1 rows x 51 columns]

# %%
gdf.rename(columns={
                'B19013_001E':'Median HH Income', 'B25003_001E':'Total Occupied','B25003_002E':'Owner Occupied','B25003_003E':'Renter Occupied',
            'B02001_001E': 'Total Pop',
                'B02001_002E':'White alone',
                "B02001_003E": "Black or African American alone", 
                "B02001_004E": "American Indian and Alaska Native alone",
                "B02001_005E": "Asian alone",
                "B02001_006E": "Native Hawaiian and Other Pacific Islander alone",
                "B02001_007E": "Some other race alone",
                "B02001_008E": "Two or more races:",
                "B02001_009E": "Two races including Some other race",
                "B02001_010E": "Two races excluding Some other race, and three or more races"}, inplace=True)

# %%
gdf = gdf[['Median HH Income',
 'Total Occupied',
 'Owner Occupied',
 'Renter Occupied',
 'state_x',
 'county_x',
 'tract',
 'Total Pop',
 'White alone',
 'Black or African American alone',
 'American Indian and Alaska Native alone',
 'Asian alone',
 'Native Hawaiian and Other Pacific Islander alone',
 'Some other race alone',
 'Two or more races:',
 'Two races including Some other race',
 'Two races excluding Some other race, and three or more races',
 'GEO_ID',
 'NAME']]

# %%
gdf.columns.values.tolist()
# Out:
# ['Median HH Income',
#  'Total Occupied',
#  'Owner Occupied',
#  'Renter Occupied',
#  'state_x',
#  'county_x',
#  'tract',
#  'Total Pop',
#  'White alone',
#  'Black or African American alone',
#  'American Indian and Alaska Native alone',
#  'Asian alone',
#  'Native Hawaiian and Other Pacific Islander alone',
#  'Some other race alone',
#  'Two or more races:',
#  'Two races including Some other race',
#  'Two races excluding Some other race, and three or more races',
#  'GEO_ID',
#  'NAME']

# %%
int_cols = ['Median HH Income',
 'Total Occupied',
 'Owner Occupied',
 'Renter Occupied',
 'Total Pop',
 'White alone',
 'Black or African American alone',
 'American Indian and Alaska Native alone',
 'Asian alone',
 'Native Hawaiian and Other Pacific Islander alone',
 'Some other race alone',
 'Two or more races:',
 'Two races including Some other race',
 'Two races excluding Some other race, and three or more races']

# %%
# Convert columns to integer data type
for column in int_cols:
    gdf[column] = gdf[column].astype(int)

# %%
race_cols = [ 'White alone',
 'Black or African American alone',
 'American Indian and Alaska Native alone',
 'Asian alone',
 'Native Hawaiian and Other Pacific Islander alone',
 'Some other race alone',
 'Two or more races:',
 'Two races including Some other race',
 'Two races excluding Some other race, and three or more races']

# %%
for col in race_cols:
    gdf["Percent " + col] = (gdf[col]/gdf['Total Pop']) * 100

# %%
gdf = gdf.drop(race_cols, axis=1)

# %%
gdf['Percent Owner Occupied'] = (gdf['Owner Occupied']/gdf['Total Occupied']) * 100
gdf['Percent Renter Occupied'] = (gdf['Renter Occupied']/gdf['Total Occupied']) * 100

# %%
gdf = gdf.drop(['Total Occupied',
 'Owner Occupied',
 'Renter Occupied',], axis=1)

# %%
gdf.head(3)
# Out:
#    Median HH Income state_x county_x   tract  Total Pop                GEO_ID  \
# 0             71775      06      065  043223       9277  1400000US06065043223
# 1            108708      06      065  043224      12791  1400000US06065043224
# 2             69173      06      065  043225       8749  1400000US06065043225
#
#                                                 NAME  Percent White alone  \
# 0  Census Tract 432.23, Riverside County, California            72.534224
# 1  Census Tract 432.24, Riverside County, California            88.507544
# 2  Census Tract 432.25, Riverside County, California            69.127900
#
#    Percent Black or African American alone  \
# 0                                 2.953541
# 1                                 1.852865
# 2                                 4.069036
#
#    Percent American Indian and Alaska Native alone  Percent Asian alone  \
# 0                                         3.859006             1.735475
# 1                                         0.508170             4.503166
# 2                                         0.000000             3.897588
#
#    Percent Native Hawaiian and Other Pacific Islander alone  \
# 0                                           0.797672
# 1                                           0.000000
# 2                                           0.000000
#
#    Percent Some other race alone  Percent Two or more races:  \
# 0                       9.604398                    8.515684
# 1                       1.798139                    2.830115
# 2                      21.362441                    1.543033
#
#    Percent Two races including Some other race  \
# 0                                     1.843268
# 1                                     1.235244
# 2                                     0.891530
#
#    Percent Two races excluding Some other race, and three or more races  \
# 0                                           6.672416
# 1                                           1.594871
# 2                                           0.651503
#
#    Percent Owner Occupied  Percent Renter Occupied
# 0               77.394090                22.605910
# 1               93.485596                 6.514404
# 2               80.186916                19.813084

# %% [markdown]
# ## Income

# %%
#Household income = table B19001

#for SB County
r = requests.get('https://api.census.gov/data/2009/acs/acs5?get=group(B19001),geometry,&for=tract:*&in=state:06&in=county:071')
censusdata = r.json()
#specify column names
column_names = censusdata[0]
data_rows = censusdata[1:]
SB_HI = pd.DataFrame(data_rows, columns=column_names)
SB_HI.head(3)
# Out:
#   B19001_001E B19001_001EA B19001_001M B19001_001MA B19001_002E B19001_002EA  \
# 0        1563         None         101         None          52         None
# 1        1808         None          51         None          39         None
# 2        1782         None          76         None          93         None
#
#   B19001_002M B19001_002MA B19001_003E B19001_003EA  ... B19001_016MA  \
# 0          48         None          29         None  ...         None
# 1          47         None          15         None  ...         None
# 2          74         None           0         None  ...         None
#
#   B19001_017E B19001_017EA B19001_017M B19001_017MA                GEO_ID  \
# 0         142         None          72         None  1400000US06071000103
# 1         233         None          84         None  1400000US06071000104
# 2         258         None          73         None  1400000US06071000105
#
#                                                 NAME state county   tract
# 0  Census Tract 1.03, San Bernardino County, Cali...    06    071  000103
# 1  Census Tract 1.04, San Bernardino County, Cali...    06    071  000104
# 2  Census Tract 1.05, San Bernardino County, Cali...    06    071  000105
#
# [3 rows x 73 columns]

# %%
#get it for Riverside
r = requests.get('https://api.census.gov/data/2009/acs/acs5?get=group(B19001),geometry,&for=tract:*&in=state:06&in=county:065')
censusdata = r.json()
#specify column names
column_names = censusdata[0]
data_rows = censusdata[1:]
#create dataframe
riverside_HI =  pd.DataFrame(data_rows, columns=column_names)
riverside_HI.head(2)
# Out:
#   B19001_001E B19001_001EA B19001_001M B19001_001MA B19001_002E B19001_002EA  \
# 0        2809         None         155         None          62         None
# 1        3853         None         189         None          13         None
#
#   B19001_002M B19001_002MA B19001_003E B19001_003EA  ... B19001_016MA  \
# 0          48         None          36         None  ...         None
# 1          20         None         176         None  ...         None
#
#   B19001_017E B19001_017EA B19001_017M B19001_017MA                GEO_ID  \
# 0         170         None          82         None  1400000US06065043223
# 1         704         None         183         None  1400000US06065043224
#
#                                                 NAME state county   tract
# 0  Census Tract 432.23, Riverside County, California    06    065  043223
# 1  Census Tract 432.24, Riverside County, California    06    065  043224
#
# [2 rows x 73 columns]

# %%
#Join the SB and Riverside income data
#HI_gdf = pd.merge(riverside_HI,SB_HI)

HI_gdf = pd.concat([riverside_HI,SB_HI], ignore_index=True)

# %%
HI_gdf.head(5)
# Out:
#   B19001_001E B19001_001EA B19001_001M B19001_001MA B19001_002E B19001_002EA  \
# 0        2809         None         155         None          62         None
# 1        3853         None         189         None          13         None
# 2        2675         None         168         None          53         None
# 3        2182         None         138         None         110         None
# 4        3089         None         215         None         119         None
#
#   B19001_002M B19001_002MA B19001_003E B19001_003EA  ... B19001_016MA  \
# 0          48         None          36         None  ...         None
# 1          20         None         176         None  ...         None
# 2          52         None         155         None  ...         None
# 3          58         None         100         None  ...         None
# 4          72         None         166         None  ...         None
#
#   B19001_017E B19001_017EA B19001_017M B19001_017MA                GEO_ID  \
# 0         170         None          82         None  1400000US06065043223
# 1         704         None         183         None  1400000US06065043224
# 2         105         None          74         None  1400000US06065043225
# 3         211         None         110         None  1400000US06065043304
# 4           0         None         132         None  1400000US06065043305
#
#                                                 NAME state county   tract
# 0  Census Tract 432.23, Riverside County, California    06    065  043223
# 1  Census Tract 432.24, Riverside County, California    06    065  043224
# 2  Census Tract 432.25, Riverside County, California    06    065  043225
# 3  Census Tract 433.04, Riverside County, California    06    065  043304
# 4  Census Tract 433.05, Riverside County, California    06    065  043305
#
# [5 rows x 73 columns]

# %%
#drop extra columns
HI_gdf = HI_gdf[["B19001_001E", "B19001_002E"    ,
                "B19001_003E"     ,
                "B19001_004E"    ,
                "B19001_005E"    ,
                "B19001_006E"     ,
                "B19001_007E"     , 
                "B19001_008E"    ,
                "B19001_009E"   ,
                "B19001_010E" ,
                "B19001_011E" ,
                "B19001_012E",
                "B19001_013E"  ,
                "B19001_014E",
                "B19001_015E"   ,
                "B19001_016E",
                "B19001_017E",
                'tract','GEO_ID']]

# %%
 #rename columns
HI_gdf.rename(columns={"B19001_001E":"Total:",       
                "B19001_002E":"<$10,000",       
                "B19001_003E": '$10,000-$14,999',     
                "B19001_004E":'$15,000 - $19,999',     
                "B19001_005E": '$20,000 - $24,999',     
                "B19001_006E":"$25,000 - $29,999",      
                "B19001_007E":"$30,000 - $34,999",       
                "B19001_008E":"$35,000 - $39,999",      
                "B19001_009E":  "$40,000 - $44,999",    
                "B19001_010E":  "$45,000 - $49,999",   
                "B19001_011E":  "$50,000 - $59,999",  
                "B19001_012E":  "$60,000 - $74,999",  
                "B19001_013E":  "$75,000 - $99,999",  
                "B19001_014E": "$100,000 - $124,999",    
                "B19001_015E":"$125,000 - $149,999",     
                "B19001_016E":"$150,000 - $199,999",   
                "B19001_017E": "$200,000 or more"}, inplace=True)

# %%
#get col names
#HI_gdf.columns.values.tolist()

# %%
#make list of income related cols
cols = [ '<$10,000',
 '$10,000-$14,999',
 '$15,000 - $19,999',
 '$20,000 - $24,999',
 '$25,000 - $29,999',
 '$30,000 - $34,999',
 '$35,000 - $39,999',
 '$40,000 - $44,999',
 '$45,000 - $49,999',
 '$50,000 - $59,999',
 '$60,000 - $74,999',
 '$75,000 - $99,999',
 '$100,000 - $124,999',
 '$125,000 - $149,999',
 '$150,000 - $199,999',
 '$200,000 or more']

# %%
#convert to integer
int_cols = ['Total:',
 '<$10,000',
 '$10,000-$14,999',
 '$15,000 - $19,999',
 '$20,000 - $24,999',
 '$25,000 - $29,999',
 '$30,000 - $34,999',
 '$35,000 - $39,999',
 '$40,000 - $44,999',
 '$45,000 - $49,999',
 '$50,000 - $59,999',
 '$60,000 - $74,999',
 '$75,000 - $99,999',
 '$100,000 - $124,999',
 '$125,000 - $149,999',
 '$150,000 - $199,999',
 '$200,000 or more']

for column in int_cols:
    HI_gdf[column] = HI_gdf[column].astype(int)

# %%
#get household income percentages for tracts
for col in cols:
    HI_gdf["Percent " + col] = (HI_gdf[col]/HI_gdf['Total:']) * 100

# %%
#drop old columns
HI_gdf =  HI_gdf.drop(cols, axis=1)

# %%
HI_gdf.head(1)
# Out:
#    Total:   tract                GEO_ID  Percent <$10,000  \
# 0    2809  043223  1400000US06065043223          2.207191
#
#    Percent $10,000-$14,999  Percent $15,000 - $19,999  \
# 0                 1.281595                   8.650765
#
#    Percent $20,000 - $24,999  Percent $25,000 - $29,999  \
# 0                   1.423994                   8.223567
#
#    Percent $30,000 - $34,999  Percent $35,000 - $39,999  \
# 0                   3.275187                   1.423994
#
#    Percent $40,000 - $44,999  Percent $45,000 - $49,999  \
# 0                   3.951584                   5.339979
#
#    Percent $50,000 - $59,999  Percent $60,000 - $74,999  \
# 0                   5.553578                   10.11036
#
#    Percent $75,000 - $99,999  Percent $100,000 - $124,999  \
# 0                  13.492346                    14.097544
#
#    Percent $125,000 - $149,999  Percent $150,000 - $199,999  \
# 0                    10.466358                     4.449982
#
#    Percent $200,000 or more
# 0                  6.051976

# %% [markdown]
# ## Education Level

# %%
#education level (sex by educational attainment pop 25 years and older)  = B15002 (now B15003 in more recent surveys)

# %%
#for SB County
r = requests.get('https://api.census.gov/data/2009/acs/acs5?get=group(B15002),geometry,&for=tract:*&in=state:06&in=county:071')
censusdata = r.json()
#specify column names
column_names = censusdata[0]
data_rows = censusdata[1:]
SB_educ = pd.DataFrame(data_rows, columns=column_names)
SB_educ.head()
# Out:
#   B15002_001E B15002_001EA B15002_001M B15002_001MA B15002_002E B15002_002EA  \
# 0        3091         None         273         None        1493         None
# 1        2752         None         280         None        1267         None
# 2        2584         None         167         None        1264         None
# 3        6614         None         593         None        3616         None
# 4        6291         None         432         None        3117         None
#
#   B15002_002M B15002_002MA B15002_003E B15002_003EA  ... B15002_034MA  \
# 0         205         None          30         None  ...         None
# 1         186         None           0         None  ...         None
# 2         114         None          12         None  ...         None
# 3         426         None          58         None  ...         None
# 4         303         None         208         None  ...         None
#
#   B15002_035E B15002_035EA B15002_035M B15002_035MA                GEO_ID  \
# 0          10         None          15         None  1400000US06071005300
# 1          48         None          59         None  1400000US06071007800
# 2           0         None         132         None  1400000US06071010022
# 3           3         None           5         None  1400000US06071010300
# 4           0         None         132         None  1400000US06071001301
#
#                                                 NAME state county   tract
# 0  Census Tract 53, San Bernardino County, Califo...    06    071  005300
# 1  Census Tract 78, San Bernardino County, Califo...    06    071  007800
# 2  Census Tract 100.22, San Bernardino County, Ca...    06    071  010022
# 3  Census Tract 103, San Bernardino County, Calif...    06    071  010300
# 4  Census Tract 13.01, San Bernardino County, Cal...    06    071  001301
#
# [5 rows x 145 columns]

# %%
#get it for Riverside
r = requests.get('https://api.census.gov/data/2009/acs/acs5?get=group(B15002),geometry,&for=tract:*&in=state:06&in=county:065')
censusdata = r.json()
#specify column names
column_names = censusdata[0]
data_rows = censusdata[1:]
#create dataframe
riverside_educ =  pd.DataFrame(data_rows, columns=column_names)
riverside_educ.head(2)
# Out:
#   B15002_001E B15002_001EA B15002_001M B15002_001MA B15002_002E B15002_002EA  \
# 0        1469         None         162         None         669         None
# 1        2760         None         289         None        1534         None
#
#   B15002_002M B15002_002MA B15002_003E B15002_003EA  ... B15002_034MA  \
# 0         131         None          55         None  ...         None
# 1         200         None           8         None  ...         None
#
#   B15002_035E B15002_035EA B15002_035M B15002_035MA                GEO_ID  \
# 0           0         None         132         None  1400000US06065043403
# 1          17         None          26         None  1400000US06065046402
#
#                                                 NAME state county   tract
# 0  Census Tract 434.03, Riverside County, California    06    065  043403
# 1  Census Tract 464.02, Riverside County, California    06    065  046402
#
# [2 rows x 145 columns]

# %%
educ_gdf = pd.concat([riverside_educ,SB_educ], ignore_index=True)

# %%
cols_to_keep = ['B15002_001E',
'B15002_003E',
'B15002_004E',
'B15002_005E',
'B15002_006E',
'B15002_007E',
'B15002_008E',
'B15002_009E',
'B15002_010E',
'B15002_011E',
'B15002_012E',
'B15002_013E',
'B15002_014E',
'B15002_015E',
'B15002_016E',
'B15002_017E',
'B15002_018E',
'B15002_020E',
'B15002_021E',
'B15002_022E',
'B15002_023E',
'B15002_024E',
'B15002_025E',
'B15002_026E',
'B15002_027E',
'B15002_028E',
'B15002_029E',
'B15002_030E',
'B15002_031E',
'B15002_032E',
'B15002_033E',
'B15002_034E',
'B15002_035E','GEO_ID', 'NAME','state','county','tract']

# %%
educ_gdf = educ_gdf.loc[:, cols_to_keep]

# %%
educ_gdf.head()
# Out:
#   B15002_001E B15002_003E B15002_004E B15002_005E B15002_006E B15002_007E  \
# 0        1469          55          23          39          68          17
# 1        2760           8          50          38          90          18
# 2        1583          31           0          14           0           0
# 3        1886           6           4         172          51          72
# 4        5795          18          10          20          21          29
#
#   B15002_008E B15002_009E B15002_010E B15002_011E  ... B15002_031E  \
# 0           0          63          60         190  ...         103
# 1          61         119         100         401  ...         121
# 2           0          74           0         230  ...          75
# 3           0          61          68         256  ...          48
# 4           0          67          23         628  ...         188
#
#   B15002_032E B15002_033E B15002_034E B15002_035E                GEO_ID  \
# 0          55          46           0           0  1400000US06065043403
# 1          40          29           0          17  1400000US06065046402
# 2         138          34           0           0  1400000US06065040903
# 3          43           0           8           0  1400000US06065041203
# 4         447         333          27          13  1400000US06065043808
#
#                                                 NAME state county   tract
# 0  Census Tract 434.03, Riverside County, California    06    065  043403
# 1  Census Tract 464.02, Riverside County, California    06    065  046402
# 2  Census Tract 409.03, Riverside County, California    06    065  040903
# 3  Census Tract 412.03, Riverside County, California    06    065  041203
# 4  Census Tract 438.08, Riverside County, California    06    065  043808
#
# [5 rows x 38 columns]

# %%
#get male and female columns to sum
male_cols = educ_gdf[[
 'B15002_003E',
'B15002_004E',
'B15002_005E',
'B15002_006E',
'B15002_007E',
'B15002_008E',
'B15002_009E',
'B15002_010E',
'B15002_011E',
'B15002_012E',
'B15002_013E',
'B15002_014E',
'B15002_015E',
'B15002_016E',
'B15002_017E',
'B15002_018E']]
female_cols = educ_gdf[[
'B15002_020E',
'B15002_021E',
'B15002_022E',
'B15002_023E',
'B15002_024E',
'B15002_025E',
'B15002_026E',
'B15002_027E',
'B15002_028E',
'B15002_029E',
'B15002_030E',
'B15002_031E',
'B15002_032E',
'B15002_033E',
'B15002_034E',
'B15002_035E',
]]

# %%
#rename columns to match
male_cols.rename(columns={
    'B15002_003E':'B15002_020E',
'B15002_004E':'B15002_021E',
'B15002_005E':'B15002_022E',
'B15002_006E':'B15002_023E',
'B15002_007E':'B15002_024E',
'B15002_008E':'B15002_025E',
'B15002_009E':'B15002_026E',
'B15002_010E':'B15002_027E',
'B15002_011E':'B15002_028E',
'B15002_012E':'B15002_029E',
'B15002_013E':'B15002_030E',
'B15002_014E':'B15002_031E',
'B15002_015E':'B15002_032E',
'B15002_016E':'B15002_033E',
'B15002_017E':'B15002_034E',
'B15002_018E':'B15002_035E'}, inplace=True)
# Out:
# C:\Users\cpugh\AppData\Local\Temp\ipykernel_7680\1756382224.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   male_cols.rename(columns={

# %%
#convert datatype to int
female_cols = female_cols.astype(int)
#convert datatype to int
male_cols = male_cols.astype(int)

# %%
df_sum = male_cols.add(female_cols, fill_value=0)

# %%
#add back tract column
df_sum['tract'] = educ_gdf['tract']

# %%
df_sum['Total_Educ'] = educ_gdf['B15002_001E']

# %%
df_sum.head()
# Out:
#    B15002_020E  B15002_021E  B15002_022E  B15002_023E  B15002_024E  \
# 0           63           53           58           99           17
# 1           35           99           91          126           36
# 2           31           25           84           29           42
# 3           12           59          321           51          113
# 4           27           22           39           41           65
#
#    B15002_025E  B15002_026E  B15002_027E  B15002_028E  B15002_029E  \
# 0           30          132           81          486          114
# 1           97          148          138          790          232
# 2           86           74           21          366           99
# 3           37          131           98          524           56
# 4           21          140           94         1676          602
#
#    B15002_030E  B15002_031E  B15002_032E  B15002_033E  B15002_034E  \
# 0           67          113           84           72            0
# 1          524          215          142           43            0
# 2          261          128          246           79           12
# 3          303           48          107            0           26
# 4         1046          527          890          455           80
#
#    B15002_035E   tract Total_Educ
# 0            0  043403       1469
# 1           44  046402       2760
# 2            0  040903       1583
# 3            0  041203       1886
# 4           70  043808       5795

# %%
df_sum.rename(columns={
      'B15002_020E':'No schooling completed',
'B15002_028E':'high school diploma',
'B15002_031E':'Associates degree',
'B15002_032E':'Bachelors degree',
'B15002_033E':'Masters degree',
'B15002_034E':'Professional school degree',
'B15002_035E':'Doctorate degree'
                }, inplace=True)

# %%
df_sum.head()
# Out:
#    No schooling completed  B15002_021E  B15002_022E  B15002_023E  B15002_024E  \
# 0                      63           53           58           99           17
# 1                      35           99           91          126           36
# 2                      31           25           84           29           42
# 3                      12           59          321           51          113
# 4                      27           22           39           41           65
#
#    B15002_025E  B15002_026E  B15002_027E  high school diploma  B15002_029E  \
# 0           30          132           81                  486          114
# 1           97          148          138                  790          232
# 2           86           74           21                  366           99
# 3           37          131           98                  524           56
# 4           21          140           94                 1676          602
#
#    B15002_030E  Associates degree  Bachelors degree  Masters degree  \
# 0           67                113                84              72
# 1          524                215               142              43
# 2          261                128               246              79
# 3          303                 48               107               0
# 4         1046                527               890             455
#
#    Professional school degree  Doctorate degree   tract Total_Educ
# 0                           0                 0  043403       1469
# 1                           0                44  046402       2760
# 2                          12                 0  040903       1583
# 3                          26                 0  041203       1886
# 4                          80                70  043808       5795

# %%
#create col for some school but less than highschool degree
df_sum['less_highschool'] = df_sum.iloc[:,2:8].sum(axis=1)
#create col for some school post highschool but less than secondary degree
df_sum['some_college'] = df_sum.B15002_029E + df_sum.B15002_030E

# %%
df_sum.head()
# Out:
#    No schooling completed  B15002_021E  B15002_022E  B15002_023E  B15002_024E  \
# 0                      63           53           58           99           17
# 1                      35           99           91          126           36
# 2                      31           25           84           29           42
# 3                      12           59          321           51          113
# 4                      27           22           39           41           65
#
#    B15002_025E  B15002_026E  B15002_027E  high school diploma  B15002_029E  \
# 0           30          132           81                  486          114
# 1           97          148          138                  790          232
# 2           86           74           21                  366           99
# 3           37          131           98                  524           56
# 4           21          140           94                 1676          602
#
#    B15002_030E  Associates degree  Bachelors degree  Masters degree  \
# 0           67                113                84              72
# 1          524                215               142              43
# 2          261                128               246              79
# 3          303                 48               107               0
# 4         1046                527               890             455
#
#    Professional school degree  Doctorate degree   tract Total_Educ  \
# 0                           0                 0  043403       1469
# 1                           0                44  046402       2760
# 2                          12                 0  040903       1583
# 3                          26                 0  041203       1886
# 4                          80                70  043808       5795
#
#    less_highschool  some_college
# 0              417           181
# 1              636           756
# 2              336           360
# 3              751           359
# 4              400          1648

# %%
educ_gdf = df_sum

# %%
#educ_gdf.columns.values.tolist()

# %%
#drop columns we don't need
educ_gdf = educ_gdf[[
 'Total_Educ',
 'No schooling completed',
 'high school diploma',
 'Associates degree',
 'Bachelors degree',
 'Masters degree',
 'Professional school degree',
 'Doctorate degree',
 'tract',
 'less_highschool',
 'some_college']]

# %%
cols =  ['No schooling completed',
 'high school diploma',
 'Associates degree',
 'Bachelors degree',
 'Masters degree',
 'Professional school degree',
 'Doctorate degree',
 'less_highschool',
 'some_college']

# %%
int_cols = [ 'Total_Educ','No schooling completed',
 'high school diploma',
 'Associates degree',
 'Bachelors degree',
 'Masters degree',
 'Professional school degree',
 'Doctorate degree',
 'less_highschool',
 'some_college']

# %%
# Convert columns to integer data type
for column in int_cols:
    educ_gdf[column] = educ_gdf[column].astype('int64')
# Out:
# C:\Users\cpugh\AppData\Local\Temp\ipykernel_7680\2605885157.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   educ_gdf[column] = educ_gdf[column].astype('int64')

# %%
for col in cols:
    educ_gdf["Percent " + col] = (educ_gdf[col]/educ_gdf['Total_Educ']) * 100
# Out:
# C:\Users\cpugh\AppData\Local\Temp\ipykernel_7680\122627141.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   educ_gdf["Percent " + col] = (educ_gdf[col]/educ_gdf['Total_Educ']) * 100
# C:\Users\cpugh\AppData\Local\Temp\ipykernel_7680\122627141.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   educ_gdf["Percent " + col] = (educ_gdf[col]/educ_gdf['Total_Educ']) * 100
# C:\Users\cpugh\AppData\Local\Temp\ipykernel_7680\122627141.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   educ_gdf["Percent " + col] = (educ_gdf[col]/educ_gdf['Total_Educ']) * 100
# C:\Users\cpugh\AppData\Local\Temp\ipykernel_7680\122627141.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   educ_gdf["Percent " + col] = (educ_gdf[col]/educ_gdf['Total_Educ']) * 100
# C:\Users\cpugh\AppData\Local\Temp\ipykernel_7680\122627141.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   educ_gdf["Percent " + col] = (educ_gdf[col]/educ_gdf['Total_Educ']) * 100
# C:\Users\cpugh\AppData\Local\Temp\ipykernel_7680\122627141.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   educ_gdf["Percent " + col] = (educ_gdf[col]/educ_gdf['Total_Educ']) * 100
# C:\Users\cpugh\AppData\Local\Temp\ipykernel_7680\122627141.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   educ_gdf["Percent " + col] = (educ_gdf[col]/educ_gdf['Total_Educ']) * 100
# C:\Users\cpugh\AppData\Local\Temp\ipykernel_7680\122627141.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   educ_gdf["Percent " + col] = (educ_gdf[col]/educ_gdf['Total_Educ']) * 100

# %%
educ_gdf = educ_gdf.drop(cols, axis=1)

# %%
educ_gdf.head()
# Out:
#    Total_Educ   tract  Percent No schooling completed  \
# 0        1469  043403                        4.288632
# 1        2760  046402                        1.268116
# 2        1583  040903                        1.958307
# 3        1886  041203                        0.636267
# 4        5795  043808                        0.465919
#
#    Percent high school diploma  Percent Associates degree  \
# 0                    33.083730                   7.692308
# 1                    28.623188                   7.789855
# 2                    23.120657                   8.085913
# 3                    27.783669                   2.545069
# 4                    28.921484                   9.094047
#
#    Percent Bachelors degree  Percent Masters degree  \
# 0                  5.718176                4.901293
# 1                  5.144928                1.557971
# 2                 15.540114                4.990524
# 3                  5.673383                0.000000
# 4                 15.358067                7.851596
#
#    Percent Professional school degree  Percent Doctorate degree  \
# 0                            0.000000                  0.000000
# 1                            0.000000                  1.594203
# 2                            0.758054                  0.000000
# 3                            1.378579                  0.000000
# 4                            1.380500                  1.207938
#
#    Percent less_highschool  Percent some_college
# 0                28.386658             12.321307
# 1                23.043478             27.391304
# 2                21.225521             22.741630
# 3                39.819724             19.034995
# 4                 6.902502             28.438309

# %% [markdown]
# ## Occupation

# %%
#Table B24080: Sex by Class of Worker for the Civilian Population).

# %%
#for SB County
r = requests.get('https://api.census.gov/data/2009/acs/acs5?get=group(B24080),geometry,&for=tract:*&in=state:06&in=county:071')
censusdata = r.json()
#specify column names
column_names = censusdata[0]
data_rows = censusdata[1:]
SB_oc = pd.DataFrame(data_rows, columns=column_names)
SB_oc.head()
# Out:
#   B24080_001E B24080_001EA B24080_001M B24080_001MA B24080_002E B24080_002EA  \
# 0        2446         None         243         None        1295         None
# 1        3286         None         337         None        1819         None
# 2        3159         None         356         None        1785         None
# 3        6005         None         354         None        3560         None
# 4        1476         None         165         None         819         None
#
#   B24080_002M B24080_002MA B24080_003E B24080_003EA  ... B24080_020MA  \
# 0         180         None         831         None  ...         None
# 1         204         None        1346         None  ...         None
# 2         167         None        1392         None  ...         None
# 3         298         None        2592         None  ...         None
# 4          89         None         605         None  ...         None
#
#   B24080_021E B24080_021EA B24080_021M B24080_021MA                GEO_ID  \
# 0           0         None         132         None  1400000US06071000103
# 1          11         None          17         None  1400000US06071000104
# 2           0         None         132         None  1400000US06071000105
# 3          28         None          47         None  1400000US06071000106
# 4           0         None         132         None  1400000US06071000107
#
#                                                 NAME state county   tract
# 0  Census Tract 1.03, San Bernardino County, Cali...    06    071  000103
# 1  Census Tract 1.04, San Bernardino County, Cali...    06    071  000104
# 2  Census Tract 1.05, San Bernardino County, Cali...    06    071  000105
# 3  Census Tract 1.06, San Bernardino County, Cali...    06    071  000106
# 4  Census Tract 1.07, San Bernardino County, Cali...    06    071  000107
#
# [5 rows x 89 columns]

# %%
#get it for Riverside
r = requests.get('https://api.census.gov/data/2009/acs/acs5?get=group(B24080),geometry,&for=tract:*&in=state:06&in=county:065')
censusdata = r.json()
#specify column names
column_names = censusdata[0]
data_rows = censusdata[1:]
#create dataframe
riverside_oc =  pd.DataFrame(data_rows, columns=column_names)
riverside_oc.head(2)
# Out:
#   B24080_001E B24080_001EA B24080_001M B24080_001MA B24080_002E B24080_002EA  \
# 0        4060         None         337         None        2205         None
# 1        5284         None         347         None        3099         None
#
#   B24080_002M B24080_002MA B24080_003E B24080_003EA  ... B24080_020MA  \
# 0         257         None        1540         None  ...         None
# 1         242         None        2023         None  ...         None
#
#   B24080_021E B24080_021EA B24080_021M B24080_021MA                GEO_ID  \
# 0           0         None         132         None  1400000US06065043223
# 1          15         None          24         None  1400000US06065043224
#
#                                                 NAME state county   tract
# 0  Census Tract 432.23, Riverside County, California    06    065  043223
# 1  Census Tract 432.24, Riverside County, California    06    065  043224
#
# [2 rows x 89 columns]

# %%
oc_gdf = pd.concat([riverside_oc,SB_oc], ignore_index=True)

# %%
#get male and female columns to sum
male_cols = oc_gdf[[
 'B24080_003E',
 'B24080_004E',
 'B24080_005E',
 'B24080_006E',
 'B24080_007E',
 'B24080_008E',
 'B24080_009E',
 'B24080_010E',
 'B24080_011E']]
female_cols = oc_gdf[[
 'B24080_013E',
 'B24080_014E',
 'B24080_015E',
 'B24080_016E',
 'B24080_017E',
 'B24080_018E',
 'B24080_019E',
 'B24080_020E',
 'B24080_021E',
]]

# %%
#rename columns to match
male_cols.rename(columns={
                "B24080_003E":  "Private for-profit wage and salary workers:",
                "B24080_004E": "Employee of private company workers",
                "B24080_005E":"Self-employed in own incorporated business workers",
                "B24080_006E": "Private not-for-profit wage and salary workers",
                "B24080_007E": "Local government workers",
                "B24080_008E": "State government workers",
                "B24080_009E": "Federal government workers",
                "B24080_010E":  "Self-employed in own not incorporated business workers",
                "B24080_011E": "Unpaid family workers"}, inplace=True)
female_cols.rename(columns={     
                "B24080_013E": "Private for-profit wage and salary workers:", 
                "B24080_014E": "Employee of private company workers", 
                "B24080_015E":"Self-employed in own incorporated business workers",
                "B24080_016E": "Private not-for-profit wage and salary workers",
                "B24080_017E": "Local government workers",
                "B24080_018E": "State government workers", 
                "B24080_019E": "Federal government workers",
                "B24080_020E":"Self-employed in own not incorporated business workers",  
                "B24080_021E": "Unpaid family workers"}, inplace=True)
# Out:
# C:\Users\cpugh\AppData\Local\Temp\ipykernel_7680\2738484696.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   male_cols.rename(columns={
# C:\Users\cpugh\AppData\Local\Temp\ipykernel_7680\2738484696.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_cols.rename(columns={

# %%
male_cols.head()
# Out:
#   Private for-profit wage and salary workers:  \
# 0                                        1540
# 1                                        2023
# 2                                        1810
# 3                                         839
# 4                                        1001
#
#   Employee of private company workers  \
# 0                                1475
# 1                                1654
# 2                                1743
# 3                                 729
# 4                                 993
#
#   Self-employed in own incorporated business workers  \
# 0                                                 65
# 1                                                369
# 2                                                 67
# 3                                                110
# 4                                                  8
#
#   Private not-for-profit wage and salary workers Local government workers  \
# 0                                             95                      154
# 1                                             83                      456
# 2                                             67                      202
# 3                                             69                      144
# 4                                             34                      155
#
#   State government workers Federal government workers  \
# 0                       38                         53
# 1                       52                         60
# 2                       61                         39
# 3                       41                          0
# 4                       14                         80
#
#   Self-employed in own not incorporated business workers Unpaid family workers
# 0                                                325                         0
# 1                                                408                        17
# 2                                                164                         0
# 3                                                306                         0
# 4                                                 35                         0

# %%
female_cols.head()
# Out:
#   Private for-profit wage and salary workers:  \
# 0                                        1233
# 1                                        1395
# 2                                        1077
# 3                                         672
# 4                                         686
#
#   Employee of private company workers  \
# 0                                1173
# 1                                1191
# 2                                1048
# 3                                 657
# 4                                 667
#
#   Self-employed in own incorporated business workers  \
# 0                                                 60
# 1                                                204
# 2                                                 29
# 3                                                 15
# 4                                                 19
#
#   Private not-for-profit wage and salary workers Local government workers  \
# 0                                             32                      260
# 1                                             85                      277
# 2                                             44                      317
# 3                                             90                      167
# 4                                            110                      178
#
#   State government workers Federal government workers  \
# 0                      156                          0
# 1                      147                         30
# 2                       54                         28
# 3                       46                         31
# 4                       98                         25
#
#   Self-employed in own not incorporated business workers Unpaid family workers
# 0                                                174                         0
# 1                                                236                        15
# 2                                                 77                         0
# 3                                                110                         0
# 4                                                 34                         0

# %%
#convert datatype to int
female_cols = female_cols.astype(int)

# %%
#convert to int
male_cols= male_cols.astype(int)

# %%
#sum to get total
df_sum = male_cols.add(female_cols, fill_value=0)

# %%
df_sum.head(4)
# Out:
#    Private for-profit wage and salary workers:  \
# 0                                         2773
# 1                                         3418
# 2                                         2887
# 3                                         1511
#
#    Employee of private company workers  \
# 0                                 2648
# 1                                 2845
# 2                                 2791
# 3                                 1386
#
#    Self-employed in own incorporated business workers  \
# 0                                                125
# 1                                                573
# 2                                                 96
# 3                                                125
#
#    Private not-for-profit wage and salary workers  Local government workers  \
# 0                                             127                       414
# 1                                             168                       733
# 2                                             111                       519
# 3                                             159                       311
#
#    State government workers  Federal government workers  \
# 0                       194                          53
# 1                       199                          90
# 2                       115                          67
# 3                        87                          31
#
#    Self-employed in own not incorporated business workers  \
# 0                                                499
# 1                                                644
# 2                                                241
# 3                                                416
#
#    Unpaid family workers
# 0                      0
# 1                     32
# 2                      0
# 3                      0

# %%
#add back tract column
df_sum['tract'] = oc_gdf['tract']

# %%
df_sum.head(1)
# Out:
#    Private for-profit wage and salary workers:  \
# 0                                         2773
#
#    Employee of private company workers  \
# 0                                 2648
#
#    Self-employed in own incorporated business workers  \
# 0                                                125
#
#    Private not-for-profit wage and salary workers  Local government workers  \
# 0                                             127                       414
#
#    State government workers  Federal government workers  \
# 0                       194                          53
#
#    Self-employed in own not incorporated business workers  \
# 0                                                499
#
#    Unpaid family workers   tract
# 0                      0  043223

# %%
#merge to get back geometries
oc_gdf = pd.merge(df_sum,oc_gdf,on='tract')

# %%
oc_gdf.head(1)
# Out:
#    Private for-profit wage and salary workers:  \
# 0                                         2773
#
#    Employee of private company workers  \
# 0                                 2648
#
#    Self-employed in own incorporated business workers  \
# 0                                                125
#
#    Private not-for-profit wage and salary workers  Local government workers  \
# 0                                             127                       414
#
#    State government workers  Federal government workers  \
# 0                       194                          53
#
#    Self-employed in own not incorporated business workers  \
# 0                                                499
#
#    Unpaid family workers   tract  ... B24080_020M B24080_020MA B24080_021E  \
# 0                      0  043223  ...         108         None           0
#
#   B24080_021EA B24080_021M B24080_021MA                GEO_ID  \
# 0         None         132         None  1400000US06065043223
#
#                                                 NAME state county
# 0  Census Tract 432.23, Riverside County, California    06    065
#
# [1 rows x 98 columns]

# %%
#rename total workers column
oc_gdf.rename(columns={"B24080_001E": "Total Workers:"}, inplace=True)

# %%
#oc_gdf.columns.values.tolist()

# %%
#drop columns
oc_gdf = oc_gdf[['Private for-profit wage and salary workers:',
 'Employee of private company workers',
 'Self-employed in own incorporated business workers',
 'Private not-for-profit wage and salary workers',
 'Local government workers',
 'State government workers',
 'Federal government workers',
 'Self-employed in own not incorporated business workers',
 'Unpaid family workers',
                 "Total Workers:",
 'GEO_ID','tract']]

# %%
# Convert columns to integer data type

int_cols = [  "Total Workers:",'Private for-profit wage and salary workers:',
 'Employee of private company workers',
 'Self-employed in own incorporated business workers',
 'Private not-for-profit wage and salary workers',
 'Local government workers',
 'State government workers',
 'Federal government workers',
 'Self-employed in own not incorporated business workers',
 'Unpaid family workers']

for column in int_cols:
    oc_gdf[column] = oc_gdf[column].astype('int64')

# %%
oc_gdf.head(3)
# Out:
#    Private for-profit wage and salary workers:  \
# 0                                         2773
# 1                                         3418
# 2                                         2887
#
#    Employee of private company workers  \
# 0                                 2648
# 1                                 2845
# 2                                 2791
#
#    Self-employed in own incorporated business workers  \
# 0                                                125
# 1                                                573
# 2                                                 96
#
#    Private not-for-profit wage and salary workers  Local government workers  \
# 0                                             127                       414
# 1                                             168                       733
# 2                                             111                       519
#
#    State government workers  Federal government workers  \
# 0                       194                          53
# 1                       199                          90
# 2                       115                          67
#
#    Self-employed in own not incorporated business workers  \
# 0                                                499
# 1                                                644
# 2                                                241
#
#    Unpaid family workers  Total Workers:                GEO_ID   tract
# 0                      0            4060  1400000US06065043223  043223
# 1                     32            5284  1400000US06065043224  043224
# 2                      0            3940  1400000US06065043225  043225

# %%
#get percentages
cols = [ 'Private for-profit wage and salary workers:',
 'Employee of private company workers',
 'Self-employed in own incorporated business workers',
 'Private not-for-profit wage and salary workers',
 'Local government workers',
 'State government workers',
 'Federal government workers',
 'Self-employed in own not incorporated business workers',
 'Unpaid family workers']

for col in cols:
    oc_gdf["Percent " + col] = (oc_gdf[col]/oc_gdf['Total Workers:']) * 100

# %%
#drop columns
oc_gdf = oc_gdf.drop(cols, axis=1)

# %%
##Percent Private for-profit wage and salary workers = employee of private company + self-employed  - dropping
oc_gdf = oc_gdf.drop(columns=['Percent Private for-profit wage and salary workers:'], axis=1)

# %%
oc_gdf.head()
# Out:
#    Total Workers:                GEO_ID   tract  \
# 0            4060  1400000US06065043223  043223
# 1            5284  1400000US06065043224  043224
# 2            3940  1400000US06065043225  043225
# 3            2515  1400000US06065043304  043304
# 4            2450  1400000US06065043305  043305
#
#    Percent Employee of private company workers  \
# 0                                    65.221675
# 1                                    53.841787
# 2                                    70.837563
# 3                                    55.109344
# 4                                    67.755102
#
#    Percent Self-employed in own incorporated business workers  \
# 0                                           3.078818
# 1                                          10.844058
# 2                                           2.436548
# 3                                           4.970179
# 4                                           1.102041
#
#    Percent Private not-for-profit wage and salary workers  \
# 0                                           3.128079
# 1                                           3.179410
# 2                                           2.817259
# 3                                           6.322068
# 4                                           5.877551
#
#    Percent Local government workers  Percent State government workers  \
# 0                         10.197044                          4.778325
# 1                         13.872067                          3.766086
# 2                         13.172589                          2.918782
# 3                         12.365805                          3.459245
# 4                         13.591837                          4.571429
#
#    Percent Federal government workers  \
# 0                            1.305419
# 1                            1.703255
# 2                            1.700508
# 3                            1.232604
# 4                            4.285714
#
#    Percent Self-employed in own not incorporated business workers  \
# 0                                          12.290640
# 1                                          12.187737
# 2                                           6.116751
# 3                                          16.540755
# 4                                           2.816327
#
#    Percent Unpaid family workers
# 0                       0.000000
# 1                       0.605602
# 2                       0.000000
# 3                       0.000000
# 4                       0.000000

# %% [markdown]
# ## Joining all the dataframes

# %%
#oc_gdf + educ_gdf + HI_gdf + gdf

census_df = pd.merge(gdf,HI_gdf, on = 'tract')

# %%
census_df.head()
# Out:
#    Median HH Income state_x county_x   tract  Total Pop              GEO_ID_x  \
# 0             71775      06      065  043223       9277  1400000US06065043223
# 1            108708      06      065  043224      12791  1400000US06065043224
# 2             69173      06      065  043225       8749  1400000US06065043225
# 3             67813      06      065  043304       6088  1400000US06065043304
# 4             53998      06      065  043305       8872  1400000US06065043305
#
#                                                 NAME  Percent White alone  \
# 0  Census Tract 432.23, Riverside County, California            72.534224
# 1  Census Tract 432.24, Riverside County, California            88.507544
# 2  Census Tract 432.25, Riverside County, California            69.127900
# 3  Census Tract 433.04, Riverside County, California            83.475690
# 4  Census Tract 433.05, Riverside County, California            72.576646
#
#    Percent Black or African American alone  \
# 0                                 2.953541
# 1                                 1.852865
# 2                                 4.069036
# 3                                 0.344941
# 4                                 5.094680
#
#    Percent American Indian and Alaska Native alone  ...  \
# 0                                         3.859006  ...
# 1                                         0.508170  ...
# 2                                         0.000000  ...
# 3                                         0.558476  ...
# 4                                         1.048242  ...
#
#    Percent $35,000 - $39,999  Percent $40,000 - $44,999  \
# 0                   1.423994                   3.951584
# 1                   2.180119                   1.323644
# 2                   4.224299                   4.224299
# 3                   2.428964                   3.345555
# 4                   7.154419                   5.212043
#
#    Percent $45,000 - $49,999  Percent $50,000 - $59,999  \
# 0                   5.339979                   5.553578
# 1                   1.998443                   3.607579
# 2                   1.607477                  10.467290
# 3                   1.604033                   7.516040
# 4                   3.528650                  10.877307
#
#    Percent $60,000 - $74,999  Percent $75,000 - $99,999  \
# 0                  10.110360                  13.492346
# 1                   8.590709                  16.688295
# 2                  14.579439                  17.009346
# 3                   6.416132                  11.824015
# 4                  16.704435                  14.535448
#
#    Percent $100,000 - $124,999  Percent $125,000 - $149,999  \
# 0                    14.097544                    10.466358
# 1                     8.642616                     9.317415
# 2                    14.878505                     4.785047
# 3                     9.807516                     7.974335
# 4                     7.542894                     3.431531
#
#    Percent $150,000 - $199,999 Percent $200,000 or more
# 0                     4.449982                 6.051976
# 1                    18.375292                18.271477
# 2                     5.383178                 3.925234
# 3                     9.624198                 9.670027
# 4                     2.622208                 0.000000
#
# [5 rows x 36 columns]

# %%
census_df = pd.merge(census_df,educ_gdf,on = 'tract')

# %%
census_df = pd.merge(census_df,oc_gdf,on = 'tract')

# %%
#census_gdf.rename(columns={"Total Workers:":"Total Workers","state_left":"state","county_left":"county","tract_left":"tract","NAME_left":"NAME"}, inplace=True)

# %%
census_df_2009 = census_df

# %% [markdown]
# ### Import geographies

# %%
tract_geometries = pd.read_json('tract_geometries.json')
tract_geometries.head()
